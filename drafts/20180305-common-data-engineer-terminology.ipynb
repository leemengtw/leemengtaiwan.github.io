# %% [markdown]
# ## References
# - https://towardsdatascience.com/a-beginners-guide-to-data-engineering-part-ii-47c4e7cbda71

# %% [markdown]
# * Data Backfilling
# * Data partitioning
# * Fact & Dimension Tables
# * Star schema
# * JVM-based ETL vs SQL-based ETL
# * Hive
# * Airflow
#     * Operators 分三種, Sensors, operators, transfers, 分別對應 ETL
#     * transfers: 有沒有 mongoToHive?

# %%
Hive
Airflow
